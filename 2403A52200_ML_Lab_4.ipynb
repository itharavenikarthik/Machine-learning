# %% [markdown]
# <a href="https://colab.research.google.com/github/itharavenikarthik/Machine-learning/blob/main/2403A52200_ML_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/Salary_dataset.csv')
x = df['YearsExperience']
years_experience = np.array(x)
years_experience
# Out:
# array([ 1.2,  1.4,  1.6,  2.1,  2.3,  3. ,  3.1,  3.3,  3.3,  3.8,  4. ,
#         4.1,  4.1,  4.2,  4.6,  5. ,  5.2,  5.4,  6. ,  6.1,  6.9,  7.2,
#         8. ,  8.3,  8.8,  9.1,  9.6,  9.7, 10.4, 10.6])

# %%
y =df["Salary"]
salary = np.array(y)
salary
# Out:
# array([ 39344.,  46206.,  37732.,  43526.,  39892.,  56643.,  60151.,
#         54446.,  64446.,  57190.,  63219.,  55795.,  56958.,  57082.,
#         61112.,  67939.,  66030.,  83089.,  81364.,  93941.,  91739.,
#         98274., 101303., 113813., 109432., 105583., 116970., 112636.,
#        122392., 121873.])

# %%
x = np.array(x).reshape(-1,1)
y = np.array(y).reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
# array([[10.4],
#        [ 8.8],
#        [ 4.1],
#        [ 1.2],
#        [ 2.3],
#        [ 5.2],
#        [ 3. ],
#        [ 4.2],
#        [ 4.1],
#        [ 8. ],
#        [ 1.4],
#        [ 1.6],
#        [ 9.1],
#        [ 2.1],
#        [ 7.2],
#        [ 9.6],
#        [ 6. ],
#        [10.6],
#        [ 6.9],
#        [ 3.3],
#        [ 4. ],
#        [ 4.6],
#        [ 6.1],
#        [ 3.1]])

# %%
x_test
# Out:
# array([[9.7],
#        [5. ],
#        [8.3],
#        [5.4],
#        [3.3],
#        [3.8]])

# %%
y_train
# Out:
# array([[122392.],
#        [109432.],
#        [ 56958.],
#        [ 39344.],
#        [ 39892.],
#        [ 66030.],
#        [ 56643.],
#        [ 57082.],
#        [ 55795.],
#        [101303.],
#        [ 46206.],
#        [ 37732.],
#        [105583.],
#        [ 43526.],
#        [ 98274.],
#        [116970.],
#        [ 81364.],
#        [121873.],
#        [ 91739.],
#        [ 54446.],
#        [ 63219.],
#        [ 61112.],
#        [ 93941.],
#        [ 60151.]])

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((24, 1), (6, 1), (24, 1), (6, 1))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
print("Actual Salary:",y_test[:5])
print("Predicted Salary:",y_pred[:5])
# Out:
# Actual Salary: [[112636.]
#  [ 67939.]
#  [113813.]
#  [ 83089.]
#  [ 64446.]]
# Predicted Salary: [[115791.21011287]
#  [ 71499.27809463]
#  [102597.86866063]
#  [ 75268.80422384]
#  [ 55478.79204548]]

# %%
# Out:
# Root Mean Squared Error: 812280229.6355517

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
print("R2 Score:",r2)
# Out:
# R2 Score: -1291707930.014809

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test,y_pred)
plt.plot(x_test, y_test)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Salary vs Experience")
plt.show()

# %%
plt.scatter(y_test,y_test,label="Actual Salary")
plt.scatter(y_test,y_pred,label="Predicted Salary")
plt.xlabel("Actual Salary")
plt.ylabel("Predicted Salary")
plt.title("Actual vs Predicted Salary")
plt.legend()
plt.show()

# %%
slope = model.coef_[0]
intercept = model.intercept_
print("Slope:",slope)
print("Intercept:",intercept)
# Out:
# Slope: [9423.81532303]
# Intercept: [24380.20147947]

# %%
experience = [[5]]

# %%
predicted_salary = model.predict(experience)
print("Predicted Salary:",predicted_salary)
# Out:
# Predicted Salary: [[71499.27809463]]
